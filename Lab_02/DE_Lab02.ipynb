# %% [markdown]
# # Data Engineering: Lab 02
# ---------------

# %% [markdown]
# ### Task 01: Create data frame called df_beers containing 5 names of beers, their type, alcohol value, and the brewing company.

# %%
import numpy as np
import pandas as pd

# %%
df_beers = pd.DataFrame(
{
'names': ['Heineken','Feldschlösschen','Maes','Jupiler','Chopfab'],
'types': ['nasty','mild','delicious','delicious','tasty'],
'alcohol_value': [4.1,4.9,5.2,5.4,4.6],
'brewing_company': ['Heineken_AG','Feldschlösschen_gmbh','Maes_ing','jupiler_enterprises','Feldschlösschen_gmbh']

}
)


df_beers
# Out:
#              names      types  alcohol_value       brewing_company
# 0         Heineken      nasty            4.1           Heineken_AG
# 1  Feldschlösschen       mild            4.9  Feldschlösschen_gmbh
# 2             Maes  delicious            5.2              Maes_ing
# 3          Jupiler  delicious            5.4   jupiler_enterprises
# 4          Chopfab      tasty            4.6  Feldschlösschen_gmbh

# %% [markdown]
# ### Task 02: Creating a dataframe from csv

# %% [markdown]
# ##### a) Create a DataFrame called meteorites with the meteorite_landings.csv file.

# %%
meteorites = pd.read_csv('DE_Lab02_meteorite_landings.csv',delimiter = ',')
meteorites
# Out:
#            Aachen  Valid                     L5        21   Fell  \
# 0          Aarhus  Valid                     H6     720.0   Fell
# 1            Abee  Valid                    EH4  107000.0   Fell
# 2        Acapulco  Valid            Acapulcoite    1914.0   Fell
# 3         Achiras  Valid                     L6     780.0   Fell
# 4        Adhi Kot  Valid                    EH4    4239.0   Fell
# ...           ...    ...                    ...       ...    ...
# 45710  Zillah 002  Valid                Eucrite     172.0  Found
# 45711      Zinder  Valid  Pallasite & ungrouped      46.0  Found
# 45712        Zlin  Valid                     H4       3.3  Found
# 45713   Zubkovsky  Valid                     L6    2167.0  Found
# 45714  Zulu Queen  Valid                   L3.7     200.0  Found
#
#        01/01/1880 12:00:00 AM      1    50.775    6.08333
# 0      01/01/1951 12:00:00 AM      2  56.18333   10.23333
# 1      01/01/1952 12:00:00 AM      6  54.21667 -113.00000
# 2      01/01/1976 12:00:00 AM     10  16.88333  -99.90000
# 3      01/01/1902 12:00:00 AM    370 -33.16667  -64.95000
# 4      01/01/1919 12:00:00 AM    379  32.10000   71.80000
# ...                       ...    ...       ...        ...
# 45710  01/01/1990 12:00:00 AM  31356  29.03700   17.01850
# 45711  01/01/1999 12:00:00 AM  30409  13.78333    8.96667
# 45712  01/01/1939 12:00:00 AM  30410  49.25000   17.66667
# 45713  01/01/2003 12:00:00 AM  31357  49.78917   41.50460
# 45714  01/01/1976 12:00:00 AM  30414  33.98333 -115.68333
#
# [45715 rows x 9 columns]

# %% [markdown]
# ##### b) Print the top5 entries of your DataFrame and check if everything is ok. What information is missing?

# %%
meteorites[:6]
#the header is missing
# Out:
#                 Aachen  Valid           L5        21  Fell  \
# 0               Aarhus  Valid           H6     720.0  Fell
# 1                 Abee  Valid          EH4  107000.0  Fell
# 2             Acapulco  Valid  Acapulcoite    1914.0  Fell
# 3              Achiras  Valid           L6     780.0  Fell
# 4             Adhi Kot  Valid          EH4    4239.0  Fell
# 5  Adzhi-Bogdo (stone)  Valid        LL3-6     910.0  Fell
#
#    01/01/1880 12:00:00 AM    1    50.775    6.08333
# 0  01/01/1951 12:00:00 AM    2  56.18333   10.23333
# 1  01/01/1952 12:00:00 AM    6  54.21667 -113.00000
# 2  01/01/1976 12:00:00 AM   10  16.88333  -99.90000
# 3  01/01/1902 12:00:00 AM  370 -33.16667  -64.95000
# 4  01/01/1919 12:00:00 AM  379  32.10000   71.80000
# 5  01/01/1949 12:00:00 AM  390  44.83333   95.16667

# %% [markdown]
# ##### c) Create the DataFrame again with the missing information and print the top5 entries.

# %%
meteorites = pd.read_csv('DE_Lab02_meteorite_landings.csv',  names=['name', 'nametype', 'recclass', 'mass (g)', 'fall', 'year', 'id', 'reclat', 'reclong'])
meteorites
# Out:
#              name nametype               recclass  mass (g)   fall  \
# 0          Aachen    Valid                     L5      21.0   Fell
# 1          Aarhus    Valid                     H6     720.0   Fell
# 2            Abee    Valid                    EH4  107000.0   Fell
# 3        Acapulco    Valid            Acapulcoite    1914.0   Fell
# 4         Achiras    Valid                     L6     780.0   Fell
# ...           ...      ...                    ...       ...    ...
# 45711  Zillah 002    Valid                Eucrite     172.0  Found
# 45712      Zinder    Valid  Pallasite & ungrouped      46.0  Found
# 45713        Zlin    Valid                     H4       3.3  Found
# 45714   Zubkovsky    Valid                     L6    2167.0  Found
# 45715  Zulu Queen    Valid                   L3.7     200.0  Found
#
#                          year     id    reclat    reclong
# 0      01/01/1880 12:00:00 AM      1  50.77500    6.08333
# 1      01/01/1951 12:00:00 AM      2  56.18333   10.23333
# 2      01/01/1952 12:00:00 AM      6  54.21667 -113.00000
# 3      01/01/1976 12:00:00 AM     10  16.88333  -99.90000
# 4      01/01/1902 12:00:00 AM    370 -33.16667  -64.95000
# ...                       ...    ...       ...        ...
# 45711  01/01/1990 12:00:00 AM  31356  29.03700   17.01850
# 45712  01/01/1999 12:00:00 AM  30409  13.78333    8.96667
# 45713  01/01/1939 12:00:00 AM  30410  49.25000   17.66667
# 45714  01/01/2003 12:00:00 AM  31357  49.78917   41.50460
# 45715  01/01/1976 12:00:00 AM  30414  33.98333 -115.68333
#
# [45716 rows x 9 columns]

# %% [markdown]
# ### Task 03: Extracting subsets

# %% [markdown]
# ##### a) Use the query method to extract the meteorites with mass(g) greater then 50000.

# %%
#bei speziellen Zeichen in Pandas die backticks benutzen ``
meteorites.query("`mass (g)` > 50000")
# Out:
#                name nametype            recclass   mass (g)   fall  \
# 2              Abee    Valid                 EH4   107000.0   Fell
# 27       Alfianello    Valid                  L6   228000.0   Fell
# 29          Allende    Valid                 CV3  2000000.0   Fell
# 84     Bath Furnace    Valid                  L6    86000.0   Fell
# 120        Bjurböle    Valid               L/LL4   330000.0   Fell
# ...             ...      ...                 ...        ...    ...
# 45700      Zaragoza    Valid       Iron & IVA-an   162000.0  Found
# 45705      Zerhamra    Valid     Iron & IIIAB-an   630000.0  Found
# 45707      Zhaoping    Valid  Iron & IAB complex  2000000.0  Found
# 45708      Zhigansk    Valid        Iron & IIIAB   900000.0  Found
# 45709    Zhongxiang    Valid                Iron   100000.0  Found
#
#                          year     id    reclat    reclong
# 2      01/01/1952 12:00:00 AM      6  54.21667 -113.00000
# 27     01/01/1883 12:00:00 AM    466  45.26667   10.15000
# 29     01/01/1969 12:00:00 AM   2278  26.96667 -105.31667
# 84     01/01/1902 12:00:00 AM   4975  38.25000  -83.75000
# 120    01/01/1899 12:00:00 AM   5064  60.40000   25.80000
# ...                       ...    ...       ...        ...
# 45700                     NaN  48916  41.65000   -0.86667
# 45705  01/01/1967 12:00:00 AM  30403  29.85861   -2.64500
# 45707  01/01/1983 12:00:00 AM  54609  24.23333  111.18333
# 45708  01/01/1966 12:00:00 AM  30405  68.00000  128.30000
# 45709  01/01/1981 12:00:00 AM  30406  31.20000  112.50000
#
# [459 rows x 9 columns]

# %% [markdown]
# ##### b) Use the query method to extract the meteorites with mass(g) greater then 50000 and fall equals 'Fell' and nametype equals 'Valid'.

# %%
# with and function all parameters together, equals is ==, the searched string has to be between ''
meteorites.query("`mass (g)` > 50000 and fall == 'Fell' and nametype == 'Valid'")
# Out:
#               name nametype            recclass   mass (g)  fall  \
# 2             Abee    Valid                 EH4   107000.0  Fell
# 27      Alfianello    Valid                  L6   228000.0  Fell
# 29         Allende    Valid                 CV3  2000000.0  Fell
# 84    Bath Furnace    Valid                  L6    86000.0  Fell
# 120       Bjurböle    Valid               L/LL4   330000.0  Fell
# ...            ...      ...                 ...        ...   ...
# 1077      Xingyang    Valid                  H6    75500.0  Fell
# 1082      Yardymly    Valid  Iron & IAB complex   150200.0  Fell
# 1091           Zag    Valid                H3-6   175000.0  Fell
# 1097         Zavid    Valid                  L6    95000.0  Fell
# 1101    Zhovtnevyi    Valid                  H6   107000.0  Fell
#
#                         year     id    reclat    reclong
# 2     01/01/1952 12:00:00 AM      6  54.21667 -113.00000
# 27    01/01/1883 12:00:00 AM    466  45.26667   10.15000
# 29    01/01/1969 12:00:00 AM   2278  26.96667 -105.31667
# 84    01/01/1902 12:00:00 AM   4975  38.25000  -83.75000
# 120   01/01/1899 12:00:00 AM   5064  60.40000   25.80000
# ...                      ...    ...       ...        ...
# 1077  01/01/1977 12:00:00 AM  24346  32.33333  114.31667
# 1082  01/01/1959 12:00:00 AM  30352  38.93333   48.25000
# 1091  01/01/1998 12:00:00 AM  30384  27.33333   -9.33333
# 1097  01/01/1897 12:00:00 AM  30396  44.40000   19.11667
# 1101  01/01/1938 12:00:00 AM  30407  47.58333   37.25000
#
# [89 rows x 9 columns]

# %% [markdown]
# ##### c) Use the query method to extract the meteorites with mass(g) greater then 100000 and the substring 'ur' in the name.

# %%
#with query and the and i connect both searches. with str.contains i'am searching for the substring in '' and brackets.
meteorites.query("`mass (g)` > 1000000 and name.str.contains ('ur') ")
# Out:
#              name nametype            recclass   mass (g)   fall  \
# 5089      Bitburg    Valid  Iron & IAB complex  1500000.0  Found
# 5575   Cranbourne    Valid       Iron & IAB-MG  8600000.0  Found
# 16368     Henbury    Valid        Iron & IIIAB  2000000.0  Found
# 26317  Murnpeowie    Valid           Iron & IC  1143000.0  Found
#
#                          year     id    reclat    reclong
# 5089   01/01/1805 12:00:00 AM   5062  49.96667    6.53333
# 5575   01/01/1854 12:00:00 AM   5463 -38.10000  145.30000
# 16368  01/01/1931 12:00:00 AM  11872 -24.56667  133.16667
# 26317  01/01/1909 12:00:00 AM  16878 -29.58333  139.90000

# %% [markdown]
# ### Task 04:  Working with the dataframe

# %% [markdown]
# ##### a) Add a column with the name 'just_year' which contains only the year of the 'year' column.

# %%
# new column with [] and then meteorites.year for the column(year),str to extract them from the date format and then slice the position to extract only the year.
meteorites['just_year'] = meteorites.year.str.slice(6,10)
meteorites
# Out:
#              name nametype               recclass  mass (g)   fall  \
# 0          Aachen    Valid                     L5      21.0   Fell
# 1          Aarhus    Valid                     H6     720.0   Fell
# 2            Abee    Valid                    EH4  107000.0   Fell
# 3        Acapulco    Valid            Acapulcoite    1914.0   Fell
# 4         Achiras    Valid                     L6     780.0   Fell
# ...           ...      ...                    ...       ...    ...
# 45711  Zillah 002    Valid                Eucrite     172.0  Found
# 45712      Zinder    Valid  Pallasite & ungrouped      46.0  Found
# 45713        Zlin    Valid                     H4       3.3  Found
# 45714   Zubkovsky    Valid                     L6    2167.0  Found
# 45715  Zulu Queen    Valid                   L3.7     200.0  Found
#
#                          year     id    reclat    reclong just_year
# 0      01/01/1880 12:00:00 AM      1  50.77500    6.08333      1880
# 1      01/01/1951 12:00:00 AM      2  56.18333   10.23333      1951
# 2      01/01/1952 12:00:00 AM      6  54.21667 -113.00000      1952
# 3      01/01/1976 12:00:00 AM     10  16.88333  -99.90000      1976
# 4      01/01/1902 12:00:00 AM    370 -33.16667  -64.95000      1902
# ...                       ...    ...       ...        ...       ...
# 45711  01/01/1990 12:00:00 AM  31356  29.03700   17.01850      1990
# 45712  01/01/1999 12:00:00 AM  30409  13.78333    8.96667      1999
# 45713  01/01/1939 12:00:00 AM  30410  49.25000   17.66667      1939
# 45714  01/01/2003 12:00:00 AM  31357  49.78917   41.50460      2003
# 45715  01/01/1976 12:00:00 AM  30414  33.98333 -115.68333      1976
#
# [45716 rows x 10 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### b) Then add a column 'age', which contains the difference of the current year and the data in the 'just_year' column. For all entries with NaN in the year column set the age to 0.

# %%
#new column automatically connected with 0
#second one converts everything in to a numeric like a int or float
#third row substract the year of th meteorite from the actual to find the difference and the actual age
# transpose the frame to get a better view on the data
meteorites['age'] = 0
meteorites['just_year'] = pd.to_numeric(meteorites['just_year'])
meteorites['age'] = 2021 - meteorites['just_year']
meteorites.T
# Out:
#                             0                       1      \
# name                       Aachen                  Aarhus
# nametype                    Valid                   Valid
# recclass                       L5                      H6
# mass (g)                     21.0                   720.0
# fall                         Fell                    Fell
# year       01/01/1880 12:00:00 AM  01/01/1951 12:00:00 AM
# id                              1                       2
# reclat                     50.775                56.18333
# reclong                   6.08333                10.23333
# just_year                  1880.0                  1951.0
# age                         141.0                    70.0
#
#                             2                       3      \
# name                         Abee                Acapulco
# nametype                    Valid                   Valid
# recclass                      EH4             Acapulcoite
# mass (g)                 107000.0                  1914.0
# fall                         Fell                    Fell
# year       01/01/1952 12:00:00 AM  01/01/1976 12:00:00 AM
# id                              6                      10
# reclat                   54.21667                16.88333
# reclong                    -113.0                   -99.9
# just_year                  1952.0                  1976.0
# age                          69.0                    45.0
#
#                             4                       5      \
# name                      Achiras                Adhi Kot
# nametype                    Valid                   Valid
# recclass                       L6                     EH4
# mass (g)                    780.0                  4239.0
# fall                         Fell                    Fell
# year       01/01/1902 12:00:00 AM  01/01/1919 12:00:00 AM
# id                            370                     379
# reclat                  -33.16667                    32.1
# reclong                    -64.95                    71.8
# just_year                  1902.0                  1919.0
# age                         119.0                   102.0
#
#                             6                       7      \
# name          Adzhi-Bogdo (stone)                    Agen
# nametype                    Valid                   Valid
# recclass                    LL3-6                      H5
# mass (g)                    910.0                 30000.0
# fall                         Fell                    Fell
# year       01/01/1949 12:00:00 AM  01/01/1814 12:00:00 AM
# id                            390                     392
# reclat                   44.83333                44.21667
# reclong                  95.16667                 0.61667
# just_year                  1949.0                  1814.0
# age                          72.0                   207.0
#
#                             8                       9      ...  \
# name                       Aguada           Aguila Blanca  ...
# nametype                    Valid                   Valid  ...
# recclass                       L6                       L  ...
# mass (g)                   1620.0                  1440.0  ...
# fall                         Fell                    Fell  ...
# year       01/01/1930 12:00:00 AM  01/01/1920 12:00:00 AM  ...
# id                            398                     417  ...
# reclat                      -31.6               -30.86667  ...
# reclong                 -65.23333                  -64.55  ...
# just_year                  1930.0                  1920.0  ...
# age                          91.0                   101.0  ...
#
#                             45706                   45707  \
# name                      Zerkaly                Zhaoping
# nametype                    Valid                   Valid
# recclass                       H5      Iron & IAB complex
# mass (g)                  16000.0               2000000.0
# fall                        Found                   Found
# year       01/01/1956 12:00:00 AM  01/01/1983 12:00:00 AM
# id                          31354                   54609
# reclat                   52.13333                24.23333
# reclong                  81.96667               111.18333
# just_year                  1956.0                  1983.0
# age                          65.0                    38.0
#
#                             45708                   45709  \
# name                     Zhigansk              Zhongxiang
# nametype                    Valid                   Valid
# recclass             Iron & IIIAB                    Iron
# mass (g)                 900000.0                100000.0
# fall                        Found                   Found
# year       01/01/1966 12:00:00 AM  01/01/1981 12:00:00 AM
# id                          30405                   30406
# reclat                       68.0                    31.2
# reclong                     128.3                   112.5
# just_year                  1966.0                  1981.0
# age                          55.0                    40.0
#
#                             45710                   45711  \
# name                   Zillah 001              Zillah 002
# nametype                    Valid                   Valid
# recclass                       L6                 Eucrite
# mass (g)                   1475.0                   172.0
# fall                        Found                   Found
# year       01/01/1990 12:00:00 AM  01/01/1990 12:00:00 AM
# id                          31355                   31356
# reclat                     29.037                  29.037
# reclong                   17.0185                 17.0185
# just_year                  1990.0                  1990.0
# age                          31.0                    31.0
#
#                             45712                   45713  \
# name                       Zinder                    Zlin
# nametype                    Valid                   Valid
# recclass    Pallasite & ungrouped                      H4
# mass (g)                     46.0                     3.3
# fall                        Found                   Found
# year       01/01/1999 12:00:00 AM  01/01/1939 12:00:00 AM
# id                          30409                   30410
# reclat                   13.78333                   49.25
# reclong                   8.96667                17.66667
# just_year                  1999.0                  1939.0
# age                          22.0                    82.0
#
#                             45714                   45715
# name                    Zubkovsky              Zulu Queen
# nametype                    Valid                   Valid
# recclass                       L6                    L3.7
# mass (g)                   2167.0                   200.0
# fall                        Found                   Found
# year       01/01/2003 12:00:00 AM  01/01/1976 12:00:00 AM
# id                          31357                   30414
# reclat                   49.78917                33.98333
# reclong                   41.5046              -115.68333
# just_year                  2003.0                  1976.0
# age                          18.0                    45.0
#
# [11 rows x 45716 columns]

# %% [markdown]
# ### Task 05: Reading
# Take your list of the top12 most important and interesting sections of the ebook "97 Things Every Data Engineer Should Know". Read the next top3 sections of your list and write down the most important points of the section with three bullet points each.
